# %%
import pandas as pd

# %%
df = pd.read_csv('qfl_data.csv')

# %%
df.head()
# Out:
#      Registrant ID  Unnamed: 1  QFL No Name Age Range  Borrow Key  \
# 0  a1C2L00000BqCTV         NaN  Q-0738  试简主     56-65        True
# 1  a1C2L00000BqCTa         NaN  Q-0739  试简一     40-55        True
# 2  a1C2L00000BqCTf         NaN  Q-0740  试简二     18-25       False
# 3  a1C2L00000BqCTk         NaN  Q-0741  试简三     15-17       False
# 4  a1C2L00000BqHRg         NaN  Q-0773  荀福音     40-55        True
#
#    Borrow Meal Card   Camp Camp Site: Camp Site Name  Coworker  ...  \
# 0              True  ADULT        Eastern University       NaN  ...
# 1              True  ADULT        Eastern University       NaN  ...
# 2              True  YOUTH        Eastern University       NaN  ...
# 3              True  YOUTH        Cabrini University       NaN  ...
# 4             False  ADULT        Eastern University       NaN  ...
#
#   Group Member Number Registrant: Test Member Name Group: Cell Group Name  \
# 0            GMN-1005             True         试简主               Group-01
# ...

# %%
print(df.keys())
# Out:
# Index(['Registrant ID', 'Unnamed: 1', 'QFL No', 'Name', 'Age Range',
#        'Borrow Key', 'Borrow Meal Card', 'Camp', 'Camp Site: Camp Site Name',
#        'Coworker', 'Church: Church Name', 'Due Amount', 'Gender', 'Grade',
#        'Fellowship', 'Is Christian', 'Is Missionary', 'Key Deposit',
#        'Pay Special Code', 'Printed', 'Reg Fee', 'Registration: Reg No',
#        'Registration: Contact Name', 'Registration: Contact Email',
#        'Registration: Contact Phone', 'Registration: Emergency Contact Name',
#        'Registration: Emergency Contact Email',
#        'Registration: Emergency Contact Phone', 'Registration: Due Amount',
#        'Registration: Paid Amount', 'Registration: Donation Amount',
#        'Registration: Owe Amount', 'Registration: Paid',
#        'Registration: Financial Note', 'Registration: Payment Method',
#        'T Shirt Size', 'Registration: Share Room',
#        'Registration: User Comment', 'Registration: Zipcode',
# ...

# %%
REGNO = "R23-0467"

# df.loc[df["Registration: Reg No"] == REGNO]
participants = []

for index, row in df.loc[df["Registration: Reg No"] == REGNO].iterrows():
    participant = {}
    for key in df.keys():
        participant[key] = row.loc[key]
    print(participant)
    participants.append(participant)
    

print(participants)
# Out:
# {'Registrant ID': 'a1C2L00000BqCTV', 'Unnamed: 1': nan, 'QFL No': 'Q-0738', 'Name': '试简主', 'Age Range': '56-65', 'Borrow Key': True, 'Borrow Meal Card': True, 'Camp': 'ADULT', 'Camp Site: Camp Site Name': 'Eastern University', 'Coworker': nan, 'Church: Church Name': 'Rutgers Community Christian Church', 'Due Amount': '$236.00', 'Gender': 'MALE', 'Grade': nan, 'Fellowship': 'Berkeley Heights 1', 'Is Christian': True, 'Is Missionary': False, 'Key Deposit': '$20.00', 'Pay Special Code': nan, 'Printed': False, 'Reg Fee': '$210.00', 'Registration: Reg No': 'R23-0467', 'Registration: Contact Name': '试简主', 'Registration: Contact Email': 'qfl@rccc.org', 'Registration: Contact Phone': '(732)-123-4567', 'Registration: Emergency Contact Name': '试简一', 'Registration: Emergency Contact Email': nan, 'Registration: Emergency Contact Phone': '(732)-123-4568', 'Registration: Due Amount': '$662.00', 'Registration: Paid Amount': '$0.00', 'Registration: Donation Amount': nan, 'Registration: Owe Amount': 
# ...
